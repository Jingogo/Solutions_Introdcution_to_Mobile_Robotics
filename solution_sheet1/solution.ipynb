# %%
from src.myfirstscript import firstFunction
import numpy as np
import matplotlib.pyplot as plt

# %%
def firstFunction(x):
  return math.cos(x)*math.exp(x)

# %%
x = np.linspace(-2*np.pi, 2*np.pi)
y = [firstFunction(i) for i in x]
plt.plot(x,y)
plt.savefig("firstFuction.png")
